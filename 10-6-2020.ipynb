# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill'].hist()

# %%
plt.hist(tips['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
tips['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
np.linspace(3.07,50,11)
# Out:
# array([ 3.07 ,  7.763, 12.456, 17.149, 21.842, 26.535, 31.228, 35.921,
#        40.614, 45.307, 50.   ])

# %%
((tips['total_bill']>=3.07) & (tips['total_bill']<=7.844)).sum()
# Out:
# 7

# %%
sns.distplot(tips['total_bill'],kde=False)

# %%
sns.distplot(tips['total_bill'],kde=False)

# %%
sns.relplot("total_bill","tip",data=tips,col='smoker')

# %%
sns.relplot("total_bill","tip",data=tips,hue='smoker')

# %%
sns.relplot("total_bill","tip",data=tips,hue='smoker',col='sex')

# %%
sns.relplot("total_bill","tip",data=tips,hue='smoker',style='smoker')

# %%
sns.__version__### double underscore at the begining and end
# Out:
# '0.9.0'

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
sns.relplot("total_bill","tip",data=tips)

# %%
sns.catplot("total_bill",'tip',data=tips,hue='smoker')

# %%
sns.catplot("total_bill",'tip',data=tips,kind='swarm',hue='smoker')

# %%
sns.catplot("total_bill",'tip',data=tips,kind='swarm',hue='smoker',col='sex')

# %%
sns.relplot("total_bill",'tip',data=tips,kind='line')

# %%
sns.catplot("day",'tip',data=tips,kind='box')

# %%
sns.catplot("day",'total_bill',data=tips,kind='box')

# %%
sns.catplot("day",'tip',data=tips,kind='box',hue='sex')## hue to see both male and female

# %%
sns.catplot("day",data=tips,kind='count')

# %%
sns.catplot("day",data=tips,kind='count',hue='smoker')

# %%
sns.catplot("day",data=tips,kind='count',hue='smoker',hue_order=
            ['No','yes'])

# %%
sns.boxplot(tips['tip'])

# %%
sns.boxplot(y=tips['tip'])

# %%
sns.boxplot(y=tips['tip'],hue='smoker',data=tips)

# %%
### distribution:
sns.distplot(tips['tip'])

# %%
sns.distplot(tips['tip'],kde=False)

# %%
sns.distplot(tips['tip'],hist=False)

# %%
sns.distplot(tips['tip'],kde=False,rug='True')

# %%
sns.distplot(tips['tip'],rug=True)

# %%
### jointplot
sns.jointplot('total_bill','tip',data=tips)

# %%
sns.jointplot('total_bill','tip',data=tips,kind='kde')### kde kanal density info

# %% [markdown]
# - 'tip' -t
# - 'total_bill' - tb
# - 'size' -s
# - relplot
# - scatterplot

# %%
combination
t,tb
t,s
tb,s
tb,t
s,t
s,tb

# %%
tips.dtypes!='category'
# Out:
# total_bill     True
# tip            True
# sex           False
# smoker        False
# day           False
# time          False
# size           True
# dtype: bool

# %%
num_col=tips.columns[tips.dtypes!='category']

# %%
for i in range (len(num_col)):
    for j in range (len(num_col)):
        print(num_col[i],num_col[j])
# Out:
# total_bill total_bill
# total_bill tip
# total_bill size
# tip total_bill
# tip tip
# tip size
# size total_bill
# size tip
# size size

# %%
val=1
for i in range(len(num_col)):
    for j in range(len(num_col)):
        plt.subplot(3,3,val)
        plt.scatter(tips[num_col[i]],tips[num_col[j]])
        plt.title(num_col[i]+'_'+num_col[j])
        val+=1
