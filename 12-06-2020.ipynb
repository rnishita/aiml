# %%
import scipy
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
scipy.__version__
# Out:
# '1.4.1'

# %%
# !pip install scipy==1.4.1
# Out:
# Requirement already satisfied: scipy==1.4.1 in c:\anaconda\nishita monica\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\anaconda\nishita monica\anaconda3\lib\site-packages (from scipy==1.4.1) (1.16.5)

# %%
import scipy.io as sio
array=np.ones((4,4))
sio.savemat('example.mat',{"ar":array})

# %%
scipy.__version__
# Out:
# '1.4.1'

# %% [markdown]
# ## linear algebra

# %%
from scipy import linalg
ar2=np.array([[4,5],[3,2]])
linalg.det(ar2)
# Out:
# -7.0

# %%
linalg.inv(ar2)
# Out:
# array([[-0.28571429,  0.71428571],
#        [ 0.42857143, -0.57142857]])

# %%
from scipy import misc
data=misc.face()
plt.imshow(data)

# %% [markdown]
# ### image operations

# %%
data.shape,type(data)
# Out:
# ((768, 1024, 3), numpy.ndarray)

# %%
flip_data=np.flipud(data)
plt.imshow(flip_data)

# %%
rand_arr=np.random.randint(low=0,high=255,size=data.shape)
plt.imshow(rand_arr)

# %%
from scipy import ndimage
data_rotate=ndimage.rotate(data,45)
plt.imshow(data_rotate)

# %%
from scipy import ndimage
data_rotate=ndimage.rotate(data,135)
plt.imshow(data_rotate)
